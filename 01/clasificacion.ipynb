# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data/drug200.csv")

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
# Edad
df.min()
# Out:
# Age               15
# Sex                F
# BP              HIGH
# Cholesterol     HIGH
# Na_to_K        6.269
# Drug           DrugY
# dtype: object

# %%
df.max()
# Out:
# Age                74
# Sex                 M
# BP             NORMAL
# Cholesterol    NORMAL
# Na_to_K        38.247
# Drug            drugX
# dtype: object

# %%
plt.figure(figsize=(9,5))
sns.displot(df.Age, kde=True)
# Out:
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Genero
df.Sex.value_counts()
# Out:
# Sex
# M    104
# F     96
# Name: count, dtype: int64

# %%
# Presión sanguinea
df.BP.value_counts()
# Out:
# BP
# HIGH      77
# LOW       64
# NORMAL    59
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,5))
sns.histplot(data=df, x="BP", hue="BP")
# Out:
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='BP', ylabel='Count'>

# %%
plt.figure(figsize=(9,5))
sns.histplot(data=df, x="Cholesterol", hue="Cholesterol")
# Out:
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Cholesterol', ylabel='Count'>

# %%
plt.figure(figsize=(9,3))
sns.displot(df.Na_to_K, kde=True)
# Out:
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(9,5))
sns.histplot(data=df, x="Drug", hue="Drug")
# Out:
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Drug', ylabel='Count'>

# %%
plt.figure(figsize=(9,5))
sns.swarmplot(data=df, x="Drug", y="Age", hue="Drug")
plt.legend(df.Drug.value_counts().index)
plt.title("Distribución de edades por droga")
# Out:
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribución de edades por droga')

# %%
df.Drug.value_counts()
# Out:
# Drug
# DrugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: count, dtype: int64

# %%
df_Sex_Drogas = df.groupby(["Drug", "Sex"]).size().reset_index(name="count")
df_Sex_Drogas
# Out:
#     Drug Sex  count
# 0  DrugY   F     47
# 1  DrugY   M     44
# 2  drugA   F      9
# 3  drugA   M     14
# 4  drugB   F      6
# 5  drugB   M     10
# 6  drugC   F      7
# 7  drugC   M      9
# 8  drugX   F     27
# 9  drugX   M     27

# %%
plt.figure(figsize=(9,5))
sns.barplot(x='Drug', y='count', hue='Sex', data=df_Sex_Drogas)
# Out:
# <Axes: xlabel='Drug', ylabel='count'>

# %%
df_BP_Drug = df.groupby(["Drug", "BP"]).size().reset_index(name="count")
df_BP_Drug
# Out:
#     Drug      BP  count
# 0  DrugY    HIGH     38
# 1  DrugY     LOW     30
# 2  DrugY  NORMAL     23
# 3  drugA    HIGH     23
# 4  drugB    HIGH     16
# 5  drugC     LOW     16
# 6  drugX     LOW     18
# 7  drugX  NORMAL     36

# %%
plt.figure(figsize=(9,5))
sns.barplot(x='Drug', y='count', hue='BP', data=df_BP_Drug)
# Out:
# <Axes: xlabel='Drug', ylabel='count'>

# %%
df_HD_Drug = df.groupby(["Drug", "Cholesterol"]).size().reset_index(name="count")
df_HD_Drug
# Out:
#     Drug Cholesterol  count
# 0  DrugY        HIGH     47
# 1  DrugY      NORMAL     44
# 2  drugA        HIGH     12
# 3  drugA      NORMAL     11
# 4  drugB        HIGH      8
# 5  drugB      NORMAL      8
# 6  drugC        HIGH     16
# 7  drugX        HIGH     20
# 8  drugX      NORMAL     34

# %%
plt.figure(figsize=(9,5))
sns.barplot(x='Drug', y='count', hue='Cholesterol', data=df_HD_Drug)
# Out:
# <Axes: xlabel='Drug', ylabel='count'>

# %%
plt.figure(figsize=(9,5))
sns.swarmplot(data=df, x="Drug", y="Na_to_K", hue="Drug")
plt.legend(df.Drug.value_counts().index)
plt.title("Distribución de Na_to_K por droga")
# Out:
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KATANA\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Distribución de Na_to_K por droga')

# %%
df.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
def label_encoder(df, columns):
    le = LabelEncoder()
    for col in columns:
        df[col] = le.fit_transform(df[col])
    return df

# %%
df = label_encoder(df, ["Sex","BP", "Cholesterol", "Drug"])
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0     23    0   0            0   25.355     0
# 1     47    1   1            0   13.093     3
# 2     47    1   1            0   10.114     3
# 3     28    0   2            0    7.798     4
# 4     61    0   1            0   18.043     0
# ..   ...  ...  ..          ...      ...   ...
# 195   56    0   1            0   11.567     3
# 196   16    1   1            0   12.006     3
# 197   52    1   2            0    9.894     4
# 198   23    1   2            1   14.020     4
# 199   40    0   1            1   11.349     4
#
# [200 rows x 6 columns]

# %%
x = df.drop(columns=["Drug"], axis=1)
y = df["Drug"]
x.head(), y.head()
# Out:
# (   Age  Sex  BP  Cholesterol  Na_to_K
#  0   23    0   0            0   25.355
#  1   47    1   1            0   13.093
#  2   47    1   1            0   10.114
#  3   28    0   2            0    7.798
#  4   61    0   1            0   18.043,
#  0    0
#  1    3
#  2    3
#  3    4
#  4    0
#  Name: Drug, dtype: int32)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42, shuffle=True)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((150, 5), (50, 5), (150,), (50,))

# %%
from sklearn.tree import DecisionTreeClassifier
